# %%
import pandas as pd
df = pd.read_parquet("ohlcv_2020_2025.parquet")
print(df.head())
print(df.dtypes)
# Out:
# Price        Date     Close      High       Low      Open       Volume ticker  \
# Ticker                 NVDA      NVDA      NVDA      NVDA         NVDA
# 0      2020-01-02  5.971078  5.971078  5.891683  5.942207  237536000.0   NVDA
# 1      2020-01-03  5.875505  5.919310  5.826474  5.851363  205384000.0   NVDA
# 2      2020-01-06  5.900144  5.905370  5.756038  5.782171  262636000.0   NVDA
# 3      2020-01-07  5.971575  6.017371  5.883469  5.928518  314856000.0   NVDA
# 4      2020-01-08  5.982775  6.024090  5.927273  5.967344  277108000.0   NVDA
#
# Price  Close High  Low  ... Close High  Low Open Volume Close High Low Open  \
# Ticker  GOOG GOOG GOOG  ...  CRWD CRWD CRWD CRWD   CRWD   BMY  BMY BMY  BMY
# 0        NaN  NaN  NaN  ...   NaN  NaN  NaN  NaN    NaN   NaN  NaN NaN  NaN
# 1        NaN  NaN  NaN  ...   NaN  NaN  NaN  NaN    NaN   NaN  NaN NaN  NaN
# 2        NaN  NaN  NaN  ...   NaN  NaN  NaN  NaN    NaN   NaN  NaN NaN  NaN
# ...
